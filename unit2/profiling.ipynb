# %%
import pandas as pd
from ydata_profiling import ProfileReport

reviews = pd.read_csv('https://raw.githubusercontent.com/davestroud/Wine/master/winemag-data_first150k.csv', index_col = 0)
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %%
profile = ProfileReport(reviews, title = "Profiling Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.10.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-09-24 13:28:18.110233&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
reviews

# %%
"""
Cell generated by Data Wrangler.
"""
def clean_data(reviews):
    # Sort by column: 'region_1' (ascending)
    reviews = reviews.sort_values(['region_1'])
    return reviews

reviews_clean = clean_data(reviews.copy())
reviews_clean.head()
# Out:
#       country                                        description  \
# 57629   Italy  Powerful and intense in delivery, this Pecorin...
# 77956   Italy  This is a bold, bulky blend of five indigenous...
# 19103   Italy  Made from a blend of five indigenous grapes fr...
# 19041   Italy  This hearty red wine from central Italy would ...
# 66378   Italy  This luminous, golden blend of Trebbiano, Pass...
#
#                      designation  points  price       province region_1  \
# 57629                        NaN      88   55.0  Central Italy  Abruzzo
# 77956  Edizione Cinque Autoctoni      89    NaN  Central Italy  Abruzzo
# 19103  Edizione Cinque Autoctoni      90   43.0  Central Italy  Abruzzo
# 19041                     Tullum      91   22.0  Central Italy  Abruzzo
# 66378                     Tullum      90   25.0  Central Italy  Abruzzo
#
#       region_2      variety           winery
# 57629      NaN     Pecorino  Cataldi Madonna
# 77956      NaN    Red Blend          Farnese
# ...
